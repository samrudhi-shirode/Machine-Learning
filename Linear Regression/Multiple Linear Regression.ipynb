# %% [markdown]
# ## Multiple Linear Regression
#
# ### Build a model that predicts PROFIT of startups on basis of RND and MKT amounts

# %% [markdown]
# ## Step 1: Data Gathering

# %%
import pandas as pd
path = r"C:\Users\SAMRUDHI\OneDrive\Desktop\DATA SCIENCE\Data analytics\Datasets\Startups.csv"
df = pd.read_csv(path)
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# ## Step 2: Data Quality Checks

# %%
df.shape
# Out:
# (50, 5)

# %%
df.columns
# Out:
# Index(['RND', 'ADMIN', 'MKT', 'STATE', 'PROFIT'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     str
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), str(1)
# memory usage: 2.1 KB

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
# Check for missing data
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %% [markdown]
# ## Step3 : Separate X and Y features
#
#     Y : Target feature, Dependent feature => Profit
#     X : Independent features => RND, MKT

# %%
X = df[['MKT','RND']]
Y = df[['PROFIT']]

# %%
X.head()
# Out:
#          MKT        RND
# 0  471784.10  165349.20
# 1  443898.53  162597.70
# 2  407934.54  153441.51
# 3  383199.62  144372.41
# 4  366168.42  142107.34

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %% [markdown]
# ## Build the model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.score(X,Y)
# Out:
# 0.9504503015559763

# %% [markdown]
# ## Evaluation of the model
#
#     MSE
#     MAE
#     RMSE
#     R2 score => Coefficient of determination

# %% [markdown]
# ## Ypredictions = B0 + B1.RND + B2.MKT
#
# B0,B1,B2 are calculated using Gradient Descent algorithm

# %%
X.head(2)
# Out:
#          MKT       RND
# 0  471784.10  165349.2
# 1  443898.53  162597.7

# %%
model.intercept_
# Out:
# array([46975.86422072])

# %%
model.coef_
# Out:
# array([[0.02990788, 0.79658404]])

# %% [markdown]
# ## Ypredictions = 46975 + 0.0299.MKT + 0.7965.RND

# %%
# Calculate the predictions
ypreds = model.predict(X)
ypreds
# Out:
# array([[192800.45862502],
#        [189774.65948019],
#        [181405.37809703],
#        [173441.30884249],
#        [171127.62321762],
#        [162879.31081217],
#        [158028.13045422],
#        [160455.73887656],
#        [152317.8036728 ],
#        [154343.8139353 ],
#        [135011.91472396],
#        [134638.87007529],
#        [129218.39657898],
#        [127812.20546461],
#        [150192.49179713],
#        [146032.71543309],
#        [117025.89184753],
#        [130829.44473222],
#        [128882.19882756],
#        [115816.41833283],
#        [116650.89209156],
#        [118384.17070857],
#        [114990.38463925],
#        [109886.18521692],
#        [112552.18715137],
#        [102612.90924225],
#        [110990.79288437],
#        [114978.60515008],
#        [103125.01275975],
#        [102440.42409014],
#        [ 99085.21956154],
#        [ 98314.54885378],
#        [ 98864.66225433],
#        [ 97600.73044466],
#        [ 90262.64121898],
#        [ 89776.4942853 ],
#        [ 75824.23391247],
#        [ 87974.01451829],
#        [ 68631.3183233 ],
#        [ 82924.81527479],
#        [ 75049.0560307 ],
#        [ 74113.88870454],
#        [ 70234.25057356],
#        [ 60390.23285206],
#        [ 65489.72930769],
#        [ 47829.57397995],
#        [ 56909.80085883],
#        [ 46975.86422072],
#        [ 47407.6526018 ],
#        [ 48326.89446186]])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

mse = mean_squared_error(Y,ypreds)
mae = mean_absolute_error(Y,ypreds)
rmse = mse**(1/2)
r2 = r2_score(Y,ypreds)

# print the evaluation metrics
print(f"MSE : {mse}")
print(f"MAE : {mae}")
print(f"RMSE : {rmse}")
print(f"R2-score : {r2*100:.2f}%")
# Out:
# MSE : 78887897.00648756
# MAE : 6499.319940113649
# RMSE : 8881.885892449169
# R2-score : 95.05%

# %% [markdown]
# ## R2 score for the above model is around 95% which states that the model is providing accurate profit results

# %%
X.head(2)
# Out:
#          MKT       RND
# 0  471784.10  165349.2
# 1  443898.53  162597.7

# %%
preds = X.copy()
preds.head(2)
# Out:
#          MKT       RND
# 0  471784.10  165349.2
# 1  443898.53  162597.7

# %%
preds['PROFIT PREDICTED'] = ypreds.round(2)

# %%
preds.head(2)
# Out:
#          MKT       RND  PROFIT PREDICTED
# 0  471784.10  165349.2         192800.46
# 1  443898.53  162597.7         189774.66

# %%
## Save the results to a csv file
preds.to_csv("Profit Prediction using RND,MKT.csv",index=False)

# %% [markdown]
# ## Out of sample predictions:
#
# ## New data from the business is shared with you. They want you to predict profit for these MKT, RND details

# %%
sample = [160000,185000]

# %%
new_data_predictions = model.predict([sample])
new_data_predictions
# Out:
# c:\Users\SAMRUDHI\OneDrive\Desktop\DATA SCIENCE\Machine Learning\repository\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[199129.172404]])
